# %%
print ("                              ARSITEKTUR DAN ORGANISASI KOMPUTER                                     ") 
print ("1. Farry Rangian")
print ("2. Christover Lumingkewas")
print ("3. Sandy Asiking")
print ("4. Franklin Mandagi")
print ("5. Melisa Ongeteua")
print ("6. Pingkan Kondjol")
# Out:
#                               ARSITEKTUR DAN ORGANISASI KOMPUTER
# 1. Farry Rangian
# 2. Christover Lumingkewas
# 3. Sandy Asiking
# 4. Franklin Mandagi
# 5. Melisa Ongeteua
# 6. Pingkan Kondjol

# %%
print ("1. Pengertian Prosesor")
print ("   Umumnya pengertian processor ataupun sering disebut otak komputer, secara jelasnya prosesor adalah sebuah IC yang mengontrol keseluruhan jalannya sebuah sistem komputer dan digunakan sebagai pusat atau otak dengan fungsi melakukan perhitungan dan menjalankan tugas")
print ("Letak prosesor ini terdapat di motherboard, nah saat pemilihan motherboard harus disesuaikan dengan jenis soket dari prosesornya contoh untuk proscessor intel ada soket LGA maka cari motherboard dengan soket LGA juga dan proscessor AMD ada AM3+ maka harus disesuikan juga. Namun ada hal terpenting yang selalu terlupakan yaitu nilai TDP prosesor harus sesuai dengan motherboardnya seperti sudah saya bahas di tips membuat komputer rakitan. Prosesor juga sering disebut “Microprosessor”. Bagian terpenting dari prosesor adalah")
print ("Aritcmatics Logical Unit (ALU) : Melakukan semua perhitungan aritmatika (matematika) yang terjadi sesuai dengan intruksi program")
print ("Control Unit (CU) :  Pengatur lalu lintas data seperti input, dan output")
print ("Memory Unit (MU) : Alat penyimpanan kecil yang mempunyai kecepatan akses cukup tinggi")
from IPython.display import Image
Image(filename="image2.jpg", width=400, height=400)
# Out:
# 1. Pengertian Prosesor
#    Umumnya pengertian processor ataupun sering disebut otak komputer, secara jelasnya prosesor adalah sebuah IC yang mengontrol keseluruhan jalannya sebuah sistem komputer dan digunakan sebagai pusat atau otak dengan fungsi melakukan perhitungan dan menjalankan tugas
# Letak prosesor ini terdapat di motherboard, nah saat pemilihan motherboard harus disesuaikan dengan jenis soket dari prosesornya contoh untuk proscessor intel ada soket LGA maka cari motherboard dengan soket LGA juga dan proscessor AMD ada AM3+ maka harus disesuikan juga. Namun ada hal terpenting yang selalu terlupakan yaitu nilai TDP prosesor harus sesuai dengan motherboardnya seperti sudah saya bahas di tips membuat komputer rakitan. Prosesor juga sering disebut “Microprosessor”. Bagian terpenting dari prosesor adalah
# Aritcmatics Logical Unit (ALU) : Melakukan semua perhitungan aritmatika (matematika) yang terjadi sesuai dengan intruksi program
# ...

# %%
print ("2. Perkembangan Prosesor")
print ("   a. Microprocessor 4004 (1971)")
print ("   Processor di awali pada tahun 1971 dimana intel mengeluarkan processor pertamanya yang di pakai pada mesin penghitung") 
print ("buscom. Ini adalah penemuan yang memulai memasukan system cerdas kedalam mesin. Processor ini dinamakan microprocessor 4004.Chip intel 4004 ini mengawali perkembangan CPU dengan mempelopori peletakan seluruh komponen mesin hitung dalam satu IC. Pada saat ini IC mengerjakan satu tugas saja.")
from IPython.display import Image
Image(filename="a.jpg", width=300, height=300)
# Out:
# 2. Perkembangan Prosesor
#    a. Microprocessor 4004 (1971)
#    Processor di awali pada tahun 1971 dimana intel mengeluarkan processor pertamanya yang di pakai pada mesin penghitung
# buscom. Ini adalah penemuan yang memulai memasukan system cerdas kedalam mesin. Processor ini dinamakan microprocessor 4004.Chip intel 4004 ini mengawali perkembangan CPU dengan mempelopori peletakan seluruh komponen mesin hitung dalam satu IC. Pada saat ini IC mengerjakan satu tugas saja.

# %%
print ("  b. Microprocessor 8008 (1972)")
print ("    Pada tahun 1972 intel mengeluarkan microprocessor 8008 yang berkecepatan hitung 2 kali lipat dari MP sebelumnya. MP ini") 
print ("adalah mp 8 bit pertama. Mp ini juga di desain untuk mengerjakan satu pekerjaan saja.")
from IPython.display import Image
Image(filename="b.jpg", width=300, height=300)
# Out:
#   b. Microprocessor 8008 (1972)
#     Pada tahun 1972 intel mengeluarkan microprocessor 8008 yang berkecepatan hitung 2 kali lipat dari MP sebelumnya. MP ini
# adalah mp 8 bit pertama. Mp ini juga di desain untuk mengerjakan satu pekerjaan saja.

# %%
print ("  c. Microprocessor 8080 (1974)")
print ("    Pada tahun 1974 intel kembali mengeluarkan mp terbaru dengan seri 8080. Pada seri ini intel melakukan perubahan dari mp")
print ("multivoltage menjadi triple voltage, teknologi yang di pakai NMOS, lebih cepat dari seri sebelumnya yang memakai teknologi PMOS. Mp ini adalah otak pertama bagi komputer yang bernama altair.Pada saat ini pengalamatan memory sudah sampai 64")
print ("kilobyte. Kecepatanya sampai 10X mp sebelumnya.Tahun ini juga muncul mp dari produsen lain seperti MC6800 dari Motorola")
print("-1974, Z80 dari Zilog -1976 (merupakan dua rival berat), dan prosessor2 lain seri 6500 buatan MOST, Rockwell, Hyundai, WDC, NCR dst.")
from IPython.display import Image
Image(filename="c.jpg", width=400, height=400)
# Out:
#   c. Microprocessor 8080 (1974)
#     Pada tahun 1974 intel kembali mengeluarkan mp terbaru dengan seri 8080. Pada seri ini intel melakukan perubahan dari mp
# multivoltage menjadi triple voltage, teknologi yang di pakai NMOS, lebih cepat dari seri sebelumnya yang memakai teknologi PMOS. Mp ini adalah otak pertama bagi komputer yang bernama altair.Pada saat ini pengalamatan memory sudah sampai 64
# kilobyte. Kecepatanya sampai 10X mp sebelumnya.Tahun ini juga muncul mp dari produsen lain seperti MC6800 dari Motorola
# -1974, Z80 dari Zilog -1976 (merupakan dua rival berat), dan prosessor2 lain seri 6500 buatan MOST, Rockwell, Hyundai, WDC, NCR dst.

# %%
print ("   Pada tahun 1978, lahir prosesor generasi pertama, yakni seri 8086 dari Intel yang merupakan CPU 16-bit pertama. Prosesor ini dinilai terlalu mahal waktu itu, sehingga pada tahun 1979 Intel mengeluarkan rancangan ulang dengan seri 8088 yang memiliki lebar bus data eksternal sebesar 8 bit. Lalu ada prosesor generasi kedua, yakni 80186 dan 80188 yang dikeluarkan oleh Intel pada tahun 1982. Seri ini ditujukan untuk mengerjakan hal-hal yang lebih spesifik. Pada tahun tersebut Intel juga mengeluarkan prosesor dengan seri 80286. Prosesor ini sering disebut dengan nama 286 yang merupakan prosesor berjenis 16-bit. Kemampuan prosesor ini sangat jauh dibandingkan seri sebelumnya.Tahun 1993 adalah tahun akselerasi. Semenjak munculnya generasi prosesor Intel yang kelima, yakni Pentium, maka perkembangan prosesor menjadi sangat cepat, seperti sekarang yang anda lihat saat ini. Demikian adalah sejarah singkat mengenai prosesor.")
# Out:
#    Pada tahun 1978, lahir prosesor generasi pertama, yakni seri 8086 dari Intel yang merupakan CPU 16-bit pertama. Prosesor ini dinilai terlalu mahal waktu itu, sehingga pada tahun 1979 Intel mengeluarkan rancangan ulang dengan seri 8088 yang memiliki lebar bus data eksternal sebesar 8 bit. Lalu ada prosesor generasi kedua, yakni 80186 dan 80188 yang dikeluarkan oleh Intel pada tahun 1982. Seri ini ditujukan untuk mengerjakan hal-hal yang lebih spesifik. Pada tahun tersebut Intel juga mengeluarkan prosesor dengan seri 80286. Prosesor ini sering disebut dengan nama 286 yang merupakan prosesor berjenis 16-bit. Kemampuan prosesor ini sangat jauh dibandingkan seri sebelumnya.Tahun 1993 adalah tahun akselerasi. Semenjak munculnya generasi prosesor Intel yang kelima, yakni Pentium, maka perkembangan prosesor menjadi sangat cepat, seperti sekarang yang anda lihat saat ini. Demikian adalah sejarah singkat mengenai prosesor.

# %%
print ("3. Fungsi Prosesor")
print ("   Pada umumnya fungsi processor (prosesor) adalah hanya untuk memproses data yang diterima dari masukkan atau di input, kemudian akan menghasilkan pengeluaran berupa output")
print ("prosesor tidak dapat bekerja sendiri namun membutuhkkan dukungan maupun terus berhubungan dengan komponen lain terutama hardisk dan RAM. Dalam memproses sebuah data dapat dilakukan dengan waktu proses cepat atau lambat tergantung kecepatan prosesor tersebut") 
print ("Saat ini kecepatan processor yang paling tinggi ada di kecepatan 4 Gigahertz (GHz) artinya dapat membaca 4000 miliar perintah dalam sekali pengerjaannya, merupakan angka fantastis dalam perkembangan tekhnologi didunia. Bagi para gamer, pasti sudah familiar dengan istilah, “greater processor, greater gaming experience”, karena sebuah game pasti sangat berpengaruh dengan kapasitas prosesor sebuah komputer")
print ("Untuk segi pengembang atau perusahaan khusus produksi prosesor ada 2 perusahaan terkenal yaitu intel dan AMD. Dari 2 perusahaan inilah banyak membanjiri pasaran processor. Produk ke2nya tentu memiliki kelebihan dan kekurangan masing-masing. Ada yang bilang kalau ketahanan untuk di pakai berjam-jam maupun berhari-hari intel lebih dapat diandalkan sedangkan bagi para gamers AMD jadi pilihannya karena lebih baik dalam memproses grafik. Pembahasan ini akan saya bahas di lain kesempatan.")
from IPython.display import Image
Image(filename="image1.png", width=400, height=40)
# Out:
# 3. Fungsi Prosesor
#    Pada umumnya fungsi processor (prosesor) adalah hanya untuk memproses data yang diterima dari masukkan atau di input, kemudian akan menghasilkan pengeluaran berupa output
# prosesor tidak dapat bekerja sendiri namun membutuhkkan dukungan maupun terus berhubungan dengan komponen lain terutama hardisk dan RAM. Dalam memproses sebuah data dapat dilakukan dengan waktu proses cepat atau lambat tergantung kecepatan prosesor tersebut
# Saat ini kecepatan processor yang paling tinggi ada di kecepatan 4 Gigahertz (GHz) artinya dapat membaca 4000 miliar perintah dalam sekali pengerjaannya, merupakan angka fantastis dalam perkembangan tekhnologi didunia. Bagi para gamer, pasti sudah familiar dengan istilah, “greater processor, greater gaming experience”, karena sebuah game pasti sangat berpengaruh dengan kapasitas prosesor sebuah komputer
# ...

# %%
print("4. Jenis-jenis prosesor")
print("    a. Intel")
print("       Prosesor ini dibuat oleh Intel Corporation yang berpusat di USA, Prosesor Intel ini tidak diragukan lagi apabila kita menggunakan prosesor dari Intel ini. Kelebihan dari Prosesor Intel adalah:")
print("         1.Lebih tahan panas di banding prosesor pabrikan lainnya")    
print("         2.Produksinya lebih populer dulu di banding brand yang lainnya, sehingga memiliki daya jual yang sangat tinngi")    
print("         3.Memiliki kelebihan Turbo Bost, pada intel Core 13. care 15, dan core 17, sehingga mempercepat proses kerja komputer.")
from IPython.display import Image
Image(filename="intel.png", width=300, height=300)
# Out:
# 4. Jenis-jenis prosesor
#     a. Intel
#        Prosesor ini dibuat oleh Intel Corporation yang berpusat di USA, Prosesor Intel ini tidak diragukan lagi apabila kita menggunakan prosesor dari Intel ini. Kelebihan dari Prosesor Intel adalah:
#          1.Lebih tahan panas di banding prosesor pabrikan lainnya
#          2.Produksinya lebih populer dulu di banding brand yang lainnya, sehingga memiliki daya jual yang sangat tinngi
#          3.Memiliki kelebihan Turbo Bost, pada intel Core 13. care 15, dan core 17, sehingga mempercepat proses kerja komputer.

# %%
print ("    b. AMD ( Advanced Micro Deviced )")
print ("        Perusahaan AMD ini berpusat di Sunnyvale, California Amerika merupakan pesaing terberat dari Intel. Prosesor jenis ini merupakan prosesor paling disukai oleh penggemar Game, karena prosesor jenis AMD ini dilengkapi dengan VGA Ati Radeon. Kekurangan dari prosesor ini adalah penggunaan daya lebih besar dan mengakibatkan prosesornya lebih cepat panas.")
from IPython.display import Image
Image(filename="AMD.jpg", width=300, height=300)
# Out:
#     b. AMD ( Advanced Micro Deviced )
#         Perusahaan AMD ini berpusat di Sunnyvale, California Amerika merupakan pesaing terberat dari Intel. Prosesor jenis ini merupakan prosesor paling disukai oleh penggemar Game, karena prosesor jenis AMD ini dilengkapi dengan VGA Ati Radeon. Kekurangan dari prosesor ini adalah penggunaan daya lebih besar dan mengakibatkan prosesornya lebih cepat panas.

# %%
print ("    c. ARM ( Advanced RISC Machine )")
print ("        Prosesor ini dikembangkan oleh ARM Limited, prosesor ini di buat untuk mengoptimalkan tiga kategori oleh") 
print ("        sebab itu prosesor ini sering digunakan oleh perangkat handphone.music player serta router.")       
print ("          1. Aplikasi Aman")    
print ("          2. Aplikasi Platform")    
print ("          3. Tertanam Sistem Real-Time")
from IPython.display import Image
Image(filename="ARM.jpg", width=400, height=400)
# Out:
#     c. ARM ( Advanced RISC Machine )
#         Prosesor ini dikembangkan oleh ARM Limited, prosesor ini di buat untuk mengoptimalkan tiga kategori oleh
#         sebab itu prosesor ini sering digunakan oleh perangkat handphone.music player serta router.
#           1. Aplikasi Aman
#           2. Aplikasi Platform
#           3. Tertanam Sistem Real-Time
